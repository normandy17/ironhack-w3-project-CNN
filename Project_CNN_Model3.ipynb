# %% [markdown]
# # 1. Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
os.environ['TF_use_legacy_keras'] = '1'

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
class_names = ['airplane', 'automoblie', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

#visualize 10x10
fig, axes = plt.subplots(10, 10, figsize=(15, 15))
fig.suptitle('CIFAR-10 - 10 SAMPLES FOR CLASS', fontsize=16, y=1.01)

for class_idx in range(10):
  indices = np.where(y_train.flatten() == class_idx)[0]
  samples = np.random.choice(indices, 10, replace=False)
  for col, sample_idx in enumerate(samples):
    ax = axes[class_idx, col]
    ax.imshow(x_train[sample_idx])
    ax.axis('off')
    if col == 0:
      ax.set_ylabel(class_names[class_idx], fontsize=9, rotation=0, labelpad=50, va='center')

plt.tight_layout()
plt.show()

#normalize
x_train_norm = x_train.astype('float32') / 255.0
x_test_norm = x_test.astype('float32') / 255.0
print('pixel min=', x_train_norm.min(), 'pixel max=', x_train_norm.max())
# Out:
# shape labels before: (50000, 1)  ->depois: (50000, 10)
# pixel min= 0.0 pixel max= 1.0

# %% [markdown]
# # 2. Defining Model (Model Architecture)

# %%
from keras.backend import clear_session
clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD

#model 3
model3 = Sequential([
    # --- Block 1 ---
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25), # 32x32 → 16x16

    # --- Block 2 ---
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25), # 16x16 → 8x8

    # --- Block 3 ---
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25), # 8x8 → 4x4

    # --- Classifier head ---
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model3.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 356,810 (1.36 MB)
#  Trainable params: 356,810 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 3. Training

# %%
from sklearn.model_selection import train_test_split

# 90/10 train/validation split
x_train_split, x_val, y_train_split, y_val = train_test_split(
    x_train_norm, y_train,
    test_size=0.1,
    random_state=42,
    stratify=y_train
)

print(f"Training samples:   {x_train_split.shape[0]}")
print(f"Validation samples: {x_val.shape[0]}")
# Out:
# Training samples:   45000
# Validation samples: 5000

# %%
from tensorflow.keras.optimizers import Adam

model3.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model3.fit(
    x_train_split, y_train_split,
    epochs=50,
    batch_size=128,
    validation_data=(x_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.3218 - loss: 1.8272 - val_accuracy: 0.4580 - val_loss: 1.4606
# Epoch 2/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4616 - loss: 1.4855 - val_accuracy: 0.5504 - val_loss: 1.2508
# Epoch 3/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5214 - loss: 1.3376 - val_accuracy: 0.6000 - val_loss: 1.1586
# Epoch 4/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5552 - loss: 1.2458 - val_accuracy: 0.6260 - val_loss: 1.0721
# Epoch 5/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5894 - loss: 1.1580 - val_accuracy: 0.6620 - val_loss: 0.9742
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6088 - loss: 1.1009 - val_accuracy: 0.6676 - val_loss: 0.9431
# Epoch 7/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6267 - loss: 1.0579 - val_accuracy: 0.6944 - val_loss: 0.8729
# Epoch 8/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6486 - loss: 1.0022 - val_accuracy: 0.7040 - val_loss: 0.8556
# Epoch 9/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6598 - loss: 0.9758 - val_accuracy: 0.7014 - val_loss: 0.8571
# Epoch 10/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6708 - loss: 0.9458 - val_accuracy: 0.7212 - val_loss: 0.8094
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6789 - loss: 0.9213 - val_accuracy: 0.7162 - val_loss: 0.8143
# Epoch 12/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6851 - loss: 0.8993 - val_accuracy: 0.7254 - val_loss: 0.7753
# Epoch 13/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6964 - loss: 0.8749 - val_accuracy: 0.7474 - val_loss: 0.7359
# Epoch 14/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7004 - loss: 0.8599 - val_accuracy: 0.7500 - val_loss: 0.7194
# Epoch 15/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7059 - loss: 0.8400 - val_accuracy: 0.7462 - val_loss: 0.7215
# Epoch 16/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7122 - loss: 0.8282 - val_accuracy: 0.7454 - val_loss: 0.7280
# Epoch 17/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7186 - loss: 0.8079 - val_accuracy: 0.7644 - val_loss: 0.6861
# Epoch 18/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7220 - loss: 0.8022 - val_accuracy: 0.7612 - val_loss: 0.6883
# Epoch 19/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7265 - loss: 0.7812 - val_accuracy: 0.7518 - val_loss: 0.7087
# Epoch 20/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7302 - loss: 0.7693 - val_accuracy: 0.7650 - val_loss: 0.6794
# Epoch 21/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7326 - loss: 0.7630 - val_accuracy: 0.7682 - val_loss: 0.6733
# Epoch 22/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7369 - loss: 0.7515 - val_accuracy: 0.7574 - val_loss: 0.6899
# Epoch 23/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7422 - loss: 0.7385 - val_accuracy: 0.7612 - val_loss: 0.6825
# Epoch 24/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7432 - loss: 0.7304 - val_accuracy: 0.7492 - val_loss: 0.7474
# Epoch 25/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7474 - loss: 0.7265 - val_accuracy: 0.7808 - val_loss: 0.6325
# Epoch 26/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7497 - loss: 0.7120 - val_accuracy: 0.7806 - val_loss: 0.6373
# Epoch 27/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7542 - loss: 0.7087 - val_accuracy: 0.7678 - val_loss: 0.6570
# Epoch 28/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7568 - loss: 0.6937 - val_accuracy: 0.7700 - val_loss: 0.6583
# Epoch 29/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7591 - loss: 0.6890 - val_accuracy: 0.7844 - val_loss: 0.6254
# Epoch 30/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7605 - loss: 0.6845 - val_accuracy: 0.7812 - val_loss: 0.6408
# Epoch 31/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7626 - loss: 0.6754 - val_accuracy: 0.7752 - val_loss: 0.6385
# Epoch 32/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7634 - loss: 0.6764 - val_accuracy: 0.7724 - val_loss: 0.6570
# Epoch 33/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7662 - loss: 0.6663 - val_accuracy: 0.7812 - val_loss: 0.6266
# Epoch 34/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7695 - loss: 0.6600 - val_accuracy: 0.7834 - val_loss: 0.6413
# Epoch 35/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7734 - loss: 0.6481 - val_accuracy: 0.7786 - val_loss: 0.6293
# Epoch 36/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7750 - loss: 0.6456 - val_accuracy: 0.7956 - val_loss: 0.5960
# Epoch 37/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7740 - loss: 0.6413 - val_accuracy: 0.7810 - val_loss: 0.6268
# Epoch 38/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7762 - loss: 0.6393 - val_accuracy: 0.7820 - val_loss: 0.6236
# Epoch 39/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7786 - loss: 0.6314 - val_accuracy: 0.7848 - val_loss: 0.6191
# Epoch 40/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7793 - loss: 0.6302 - val_accuracy: 0.7798 - val_loss: 0.6572
# Epoch 41/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7809 - loss: 0.6245 - val_accuracy: 0.7968 - val_loss: 0.5908
# Epoch 42/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7816 - loss: 0.6261 - val_accuracy: 0.7820 - val_loss: 0.6386
# Epoch 43/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7878 - loss: 0.6130 - val_accuracy: 0.7950 - val_loss: 0.5929
# Epoch 44/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7826 - loss: 0.6128 - val_accuracy: 0.7934 - val_loss: 0.6062
# Epoch 45/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7824 - loss: 0.6186 - val_accuracy: 0.7910 - val_loss: 0.6251
# Epoch 46/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7866 - loss: 0.6083 - val_accuracy: 0.7952 - val_loss: 0.6049
# Epoch 47/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7851 - loss: 0.6151 - val_accuracy: 0.7974 - val_loss: 0.5970
# Epoch 48/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7886 - loss: 0.6059 - val_accuracy: 0.7796 - val_loss: 0.6428
# Epoch 49/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7922 - loss: 0.5949 - val_accuracy: 0.8006 - val_loss: 0.5850
# Epoch 50/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7921 - loss: 0.5918 - val_accuracy: 0.7898 - val_loss: 0.6136

# %% [markdown]
# # 4. Performance

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Get predictions on validation set
y_val_pred_probs = model3.predict(x_val)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)

# Overall loss & accuracy
val_loss, val_acc = model3.evaluate(x_val, y_val, verbose=0)
print(f"Validation Loss:     {val_loss:.4f}")
print(f"Validation Accuracy: {val_acc:.4f} ({val_acc*100:.2f}%)\n")
train_loss     = history.history['loss']
train_accuracy = history.history['accuracy']

print(f"Final Training Loss:       {train_loss[-1]:.4f}")
print(f"Final Training Accuracy:   {train_accuracy[-1]:.4f} ({train_accuracy[-1]*100:.2f}%)\n")

# Per-class report
print(classification_report(y_val, y_val_pred, target_names=class_names))

# Confusion matrix
cm = confusion_matrix(y_val, y_val_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix — Validation Set')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# Validation Loss:     0.6136
# Validation Accuracy: 0.7898 (78.98%)
#
# Final Training Loss:       0.5918
# Final Training Accuracy:   0.7921 (79.21%)
#
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.81      0.83       500
#   automoblie       0.93      0.89      0.91       500
#         bird       0.66      0.73      0.69       500
#          cat       0.60      0.65      0.62       500
#         deer       0.71      0.81      0.76       500
#          dog       0.79      0.55      0.64       500
#         frog       0.77      0.90      0.83       500
#        horse       0.86      0.79      0.82       500
#         ship       0.87      0.93      0.90       500
#        truck       0.91      0.85      0.88       500
#
#     accuracy                           0.79      5000
#    macro avg       0.80      0.79      0.79      5000
# weighted avg       0.80      0.79      0.79      5000

# %%
train_loss     = history.history['loss']
train_accuracy = history.history['accuracy']

test_loss, test_accuracy = model3.evaluate(x_test_norm, y_test, verbose=0)

print(f"Final Training Loss:     {train_loss[-1]:.4f}")
print(f"Final Training Accuracy: {train_accuracy[-1]:.4f} ({train_accuracy[-1]*100:.2f}%)")
print(f"Test Loss:               {test_loss:.4f}")
print(f"Test Accuracy:           {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
# Out:
# Final Training Loss:     0.5918
# Final Training Accuracy: 0.7921 (79.21%)
# Test Loss:               0.6361
# Test Accuracy:           0.7845 (78.45%)
